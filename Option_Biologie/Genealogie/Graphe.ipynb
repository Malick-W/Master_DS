# %%
import numpy as np
import pandas as pd

path_Home = "/home/malick/Bureau/Master_DS/Option_Biologie"
path = ""

df = pd.read_csv(path_Home + "/test16.csv",  sep=',')

# %%
# Out:
#      A1  A2  A3  A4   B1   B2  B3  B4    C1    C2  C3  C4   D1   D2  D3  D4  \
# 0    10  10   0   0   20   30   0   0   100    50   0   0   60   60   0   0
# 1    20  10   0   0   30   30   0   0    60    40   0   0   80   60   0   0
# 2    10  10   0   0   20   20   0   0    60    50   0   0   10  100   0   0
# 3   100  80   0   0   40   30   0   0   100    10   0   0   80   60   0   0
# 4    10  10   0   0   20   30   0   0   100    40   0   0   60   60   0   0
# 5    10  10   0   0   20   30   0   0    60    50   0   0   60   10   0   0
# 6    10  80   0   0   20   30   0   0   100    50   0   0   10   60   0   0
# 7    10  10   0   0   20   30   0   0   100    50   0   0   60   60   0   0
# 8   150  10   0   0  200   30   0   0  1000    50   0   0  600   60   0   0
# 9    10  10   0   0   20   30   0   0   100    50   0   0   60   60   0   0
# 10  150  10   0   0  200   30   0   0   100    50   0   0   60   60   0   0
# ...

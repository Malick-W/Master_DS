# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics.cluster import entropy



def rgb2gray(rgb):
    """ convertion d'image en gris """
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.144])

def Entropie (image):
    histogramme = np.histogram(img_1_gris.ravel(),256,[0,256],density=True)[0]
    return sum([-p*(math.log(p,2)) for p in histogramme if p > 0])

def Travailpersonnel(image):
    
    img_1 = mpimg.imread(image)    
    img_1_gris = rgb2gray(img_1)
    
    plt.figure(1)
    plt.subplot(1, 2, 1)
    plt.imshow(img_1)
    plt.imshow(img_1_gris, cmap = plt.get_cmap('gray'))
    plt.hist(img_1_gris.ravel(),256,[0,256],density=True)
    
    return entropy(img_1_gris)

# %%
path = "/users/mmath/wade/Bureau/Master_DS/Data_viz/images/im1.jpeg"

Travailpersonnel(path)
# Out:
# 2.0158748239844417

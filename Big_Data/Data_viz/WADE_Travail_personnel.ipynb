# %% [markdown]
# # Master Data Science Data_VIZ
# ### WADE El Hadji Malick

# %% [markdown]
# ## 1. Informations sur les données

# %% [raw]
# ## Data: Liste des prénoms des enfants nés à Angers de 2013 à 2018 avec le nombre d’occurrences de chaque prénom,
#          classés par année et par sexe.
#
# ## Définition des en-têtes:
#    COLL_NOM: nom de la commune
#    COLL_INSEE: Code Insee de la commune
#    ENFANT_SEXE: sexe
#    ENFANT_PRENOM: prénom
#    NOMBRE_OCCURENCES: occurrence du prénom
#    ANNEE: année de naissance

# %%
import pandas as pd

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

path = "/home/malick/Bureau/Data/Big_Data/Data_viz/prenoms-des-enfants-nes-a-angers.csv"
df = pd.read_csv(path,  sep=';')

df.iloc[1:11,2:6]
# Out:
#    ENFANT_SEXE ENFANT_PRENOM  NOMBRE_OCCURENCES  ﻿ANNEE
# 1            F      Apolline                 11    2017
# 2            F          Cléa                  4    2017
# 3            F        Maëlle                  4    2017
# 4            F     Charlotte                 20    2018
# 5            F          Alix                  7    2018
# 6            F          Anaé                  6    2018
# 7            M         Noham                  4    2013
# 8            M       Marceau                 11    2015
# 9            M       Yassine                  4    2015
# 10           M        Eliott                 20    2016

# %% [markdown]
# ## 2. Images, Histogrammes et Entropies:

# %% [raw]
# Pour chaque variable, on importe deux images en couleur(respectant et ne respectant pas les préconisations de Mackinlay), on respasse ensuite les images en niveaux de gris et on récupére les histogrammes.
# On code les fonctions permettant cela

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics.cluster import entropy # Calcul l'entropie d'une image



def rgb2gray(rgb):
    """ fonction qui convertit une image en gris """
    
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.144])


def Entropie (image):
    """ fonction qui calcule l'entropie d'une image"""
    
    histogramme = np.histogram(img_1_gris.ravel(),256,[0,256],density=True)[0]
    return sum([-p*(math.log(p,2)) for p in histogramme if p > 0])


def Travailpersonnel(path):
    """fonction qui représente une image en couleur, en gris, trace l'histogramme et affiche son entropie"""
    
    img_1 = mpimg.imread(path)    
    img_1_gris = rgb2gray(img_1)
   
    fig = plt.figure(1, figsize=(10, 4))

    
    plt.subplot(1, 3, 1)
    plt.title('Image originale')
    plt.imshow(img_1)
    
    plt.subplot(1, 3, 2)
    plt.title('Image en gris')
    plt.imshow(img_1_gris, cmap = plt.get_cmap('gray'))
    
    plt.subplot(1, 3, 3)
    plt.title('Histogramme')
    plt.hist(img_1_gris.ravel(),256,[0,256],density=True)
    
    plt.show()
    
    if entropy(img_1_gris) < 1:
        print("Entropie d'une image respectant les préconisations de Mackinlay: ", round(entropy(img_1_gris),3))
    else:
        print("Entropie d'une image ne respectant les préconisations de Mackinlay: ", round(entropy(img_1_gris),3))
    print("##############################################################################\n\n")

path = "/home/malick/Bureau/Master_DS/Big_Data/Data_viz/Images"

# %% [markdown]
# #### a. ENFANT_SEXE (Attributs nominaux)

# %%
im_1 = path + "/Colonnes_ENFANT_SEXE.png"
Travailpersonnel(im_1)
# Out:
# Entropie d'une image respectant les préconisations de Mackinlay:  0.791
# ##############################################################################

# %%
im_2 = path + "/Camembert_ENFANT_SEXE.png"
Travailpersonnel(im_2)
# Out:
# Entropie d'une image ne respectant les préconisations de Mackinlay:  1.238
# ##############################################################################

# %% [markdown]
# #### b. ENFANT_PRENOM (Attributs nominaux)

# %%
im_1 = path + "/Radar_ENFANT_PRENOM.png"
Travailpersonnel(im_1)
# Out:
# Entropie d'une image respectant les préconisations de Mackinlay:  0.911
# ##############################################################################

# %%
im_2 = path + "/Camembert_ENFANT_PRENOM.png"
Travailpersonnel(im_2)
# Out:
# Entropie d'une image ne respectant les préconisations de Mackinlay:  3.237
# ##############################################################################

# %% [markdown]
# #### c. NOMBRE_OCCURENCES (Attributs nominaux)

# %%
im_1 = path + "/Courbe_NOMBRE_OCCURENCES.png"
Travailpersonnel(im_1)
# Out:
# Entropie d'une image respectant les préconisations de Mackinlay:  0.424
# ##############################################################################

# %%
im_2 = path + "/Treemap_NOMBRE_OCCURENCES.png"
Travailpersonnel(im_2)
# Out:
# Entropie d'une image ne respectant les préconisations de Mackinlay:  2.202
# ##############################################################################

# %% [markdown]
# #### d. ANNEE (Attributs ordonnés)

# %%
im_1 = path + "/Radar_ANNEE.png"
Travailpersonnel(im_1)
# Out:
# Entropie d'une image respectant les préconisations de Mackinlay:  0.455
# ##############################################################################

# %%
im_2 = path + "/Entonnoir_ANNEE.png"
Travailpersonnel(im_2)
# Out:
# Entropie d'une image ne respectant les préconisations de Mackinlay:  1.741
# ##############################################################################

# %% [markdown]
# ## 3. Conclusion:

# %% [raw]
# La plus grande entropie (3.237) a été obtenue sur un graphe de type «Camembert» de la variable _ENFANT_PRENOM.
# Ce type de graphe est très chargé en couleur, et donc contient beaucoup de nuances de niveaux de gris.
# Les deux plus faibles entropies ont été obtenues sur des graphes de type « Radar et Courbe ». Elles s’élèvent à 0,424 et 0,455.
#
# En conclusion, si le graphe est peu chargé en couleur et contient peu d’information en terme d’occupation de l’espace, alors l’entropie est faible.
# Inversement, plus le graphe sera coloré et prendra la totalité de l’image (moins il y aura de fond blanc), plus l’entropie sera forte.
